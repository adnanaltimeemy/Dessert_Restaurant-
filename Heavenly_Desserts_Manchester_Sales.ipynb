# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# for nicer plots
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
import pandas as pd

# Path to your CSV file
csv_path = "sales_data.csv"

# Read the CSV file
df = pd.read_csv(csv_path)

# Clean column names (removes accidental spaces)
df.columns = df.columns.str.strip()

# Print actual column names
print("Columns in file:", df.columns)

# Automatically find a column that contains 'date'
date_col = None
for col in df.columns:
    if "date" in col.lower():
        date_col = col
        break

if date_col:
    df[date_col] = pd.to_datetime(df[date_col], errors="coerce")
    print(f"Converted '{date_col}' to datetime.")
else:
    print("No date column found.")

# Quick check
print(df.head())

# Check data types
print(df.dtypes)
# Out:
# Columns in file: Index(['Quarter', 'Revenue_USD_m', 'SameStoreSales_Growth_pct'], dtype='object')
# No date column found.
#    Quarter  Revenue_USD_m  SameStoreSales_Growth_pct
# 0  Q1 2025           1125                        3.0
# 1  Q2 2025           1140                        4.5
# 2  Q3 2025           1180                        5.0
# 3  Q4 2025           1200                        4.0
# Quarter                       object
# Revenue_USD_m                  int64
# SameStoreSales_Growth_pct    float64
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['quarter', 'revenue_usd_m', 'samestoresales_growth_pct'], dtype='object')

# %%
print(df.columns)
print(df.head())
# Out:
# Index(['quarter', 'revenue_usd_m', 'samestoresales_growth_pct'], dtype='object')
#    quarter  revenue_usd_m  samestoresales_growth_pct
# 0  Q1 2025           1125                        3.0
# 1  Q2 2025           1140                        4.5
# 2  Q3 2025           1180                        5.0
# 3  Q4 2025           1200                        4.0

# %%
df.columns = df.columns.str.lower()

# %%
for col in df.columns:
    print(f"'{col}'")
# Out:
# 'quarter'
# 'revenue_usd_m'
# 'samestoresales_growth_pct'

# %%
print(df.columns)
# Out:
# Index(['quarter', 'revenue_usd_m', 'samestoresales_growth_pct'], dtype='object')

# %%
globals().keys()
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', 'pd', 'np', 'plt', 'sns', '_i2', 'csv_path', '_i3', 'df', '_i4', '_i5', 'date_col', 'col', '_i6', '_i7', '_i8', '_i9', 'years_of_interest', '_i10', '_i11', '_i12', '_i13', '_i14', 'df_time', '_i15', '_i16', '_i17', '_i18', '_i19', '_i20'])

# %%
df.head()
df.columns
# Out:
# Index(['quarter', 'revenue_usd_m', 'samestoresales_growth_pct'], dtype='object')

# %%
print(df.columns.tolist())
# Out:
# ['quarter', 'revenue_usd_m', 'samestoresales_growth_pct']

# %%
df.rename(columns={"order_date": "date"}, inplace=True)
